# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer_behavior_df = pd.read_csv("../../data/dailycustomerbehavior.csv")

# %%
len(customer_behavior_df)
# Out:
# 365

# %%
customer_behavior_df.columns
# Out:
# Index(['Date', 'CTR', 'AbandonedCartRate', 'BounceRate',
#        'FunnelDrop_ViewToCart', 'FunnelDrop_CartToCheckout',
#        'ReturningVisitorRatio', 'AvgSessionDuration_sec'],
#       dtype='object')

# %% [markdown]
# #### What does each feature tell us, Looking at the mean values -
# 1. CTR is 3.27%, which is less, means people are not clicking on our advertisement -- need to work on our marketing/advertisement content.
# 2. AbandonedCartRate is 59%, meaning more than 50% people are not checking out our products even after adding them to cart.
# 3. ReturningVisitorRatio is 41%, these are our loyal customers
# 4. AvgSessionDuration_sec is 41 sec, meaning we can prepare our marketing/advertising content around these to have maximum customer eyes on our product.
# 5. FunnelDrop_ViewToCart is 49%, means around 50% of the target audience is simply viewing our product and not even adding to cart or purchasing it. Need to look our for our brand image and pricing and discount rate, etc.. Need to know whyy??
# 6. FunnelDrop_CartToCheckout is 29%, which is less, indicating a good point that our product once added to cart, gets checked out ~70% of time.
# 7. BounceRate is 37%, which is a good start -- our website is good.

# %%
customer_behavior_df.describe()
# Out:
#               CTR  AbandonedCartRate  BounceRate  FunnelDrop_ViewToCart  \
# count  365.000000         365.000000  365.000000             365.000000
# mean     0.032720           0.592364    0.376636               0.491386
# std      0.020274           0.140400    0.142152               0.142995
# min      0.002300           0.112500    0.065800               0.100800
# 25%      0.017700           0.496600    0.283600               0.390200
# 50%      0.027900           0.609900    0.367000               0.484100
# 75%      0.044500           0.696500    0.464500               0.587800
# max      0.129500           0.899300    0.812200               0.884900
#
#        FunnelDrop_CartToCheckout  ReturningVisitorRatio  \
# count                 365.000000             365.000000
# mean                    0.296694               0.417978
# std                     0.138214               0.148811
# min                     0.037000               0.057000
# ...

# %%
customer_behavior_df.head()
# Out:
#          Date     CTR  AbandonedCartRate  BounceRate  FunnelDrop_ViewToCart  \
# 0  01-01-2021  0.0360             0.6130      0.4968                 0.3854
# 1  02-01-2021  0.0323             0.4300      0.3449                 0.6291
# 2  03-01-2021  0.0258             0.4325      0.4739                 0.3540
# 3  04-01-2021  0.0143             0.4805      0.3021                 0.1288
# 4  05-01-2021  0.0427             0.5021      0.3350                 0.5039
#
#    FunnelDrop_CartToCheckout  ReturningVisitorRatio  AvgSessionDuration_sec
# 0                     0.5198                 0.2411                   83.59
# 1                     0.5160                 0.2132                   50.25
# 2                     0.3354                 0.3151                   21.43
# 3                     0.3218                 0.3321                   17.01
# 4                     0.1453                 0.3350                   35.88

# %% [markdown]
# #### We don't have any null values in competitors data

# %%
customer_behavior_df.isnull().sum()
# Out:
# Date                         0
# CTR                          0
# AbandonedCartRate            0
# BounceRate                   0
# FunnelDrop_ViewToCart        0
# FunnelDrop_CartToCheckout    0
# ReturningVisitorRatio        0
# AvgSessionDuration_sec       0
# dtype: int64

# %% [markdown]
# #### Date vs features
# 1. BounceRate(42%) is maximum in December and so is the AbandonedCartRate(63%)
# 2. There seems to be some relationship between AbandonedCartRate and BounceRate.
# 3. We can also think of some insight from FunnelDrop_ViewToCart to FunnelDrop_CartToCheckout.
# 4. Target audience is more active during the end of year (Sep-Dec), especially in September and November (Ref. from AvgSessionDuration_sec).

# %%
customer_behavior_df["Date"] = pd.to_datetime(customer_behavior_df["Date"], format='%d-%m-%Y')

# Set 'Date' as the index
customer_behavior_df.set_index('Date', inplace=True)

# %%
# Resample the data to monthly frequency and calculate the mean CTR
monthly_ctr = customer_behavior_df['CTR'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_ctr.index.strftime('%Y-%m'), y=monthly_ctr.values)
plt.title('Average Monthly CTR')
plt.xlabel('Date')
plt.ylabel('Average CTR')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %%
# Resample the data to monthly frequency and calculate the mean ACR
monthly_acr = customer_behavior_df['AbandonedCartRate'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_acr.index.strftime('%Y-%m'), y=monthly_acr.values)
plt.title('Average Monthly Abandoned Cart Rate (ACR)')
plt.xlabel('Date')
plt.ylabel('Average ACR')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %%
# Resample the data to monthly frequency and calculate the mean BounceRate
monthly_br = customer_behavior_df['BounceRate'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_br.index.strftime('%Y-%m'), y=monthly_br.values)
plt.title('Average Monthly Bounce Rate (BR)')
plt.xlabel('Date')
plt.ylabel('Average BR')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %%
# Resample the data to monthly frequency and calculate the mean FunnelDrop_ViewToCart
monthly_fd_view_to_cart = customer_behavior_df['FunnelDrop_ViewToCart'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_fd_view_to_cart.index.strftime('%Y-%m'), y=monthly_fd_view_to_cart.values)
plt.title('Average Monthly FunnelDrop_ViewToCart')
plt.xlabel('Date')
plt.ylabel('Average FunnelDrop_ViewToCart')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %%
# Resample the data to monthly frequency and calculate the mean FunnelDrop_CartToCheckout
monthly_fd_cart_to_checkout = customer_behavior_df['FunnelDrop_CartToCheckout'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_fd_cart_to_checkout.index.strftime('%Y-%m'), y=monthly_fd_cart_to_checkout.values)
plt.title('Average Monthly FunnelDrop_CartToCheckout')
plt.xlabel('Date')
plt.ylabel('Average FunnelDrop_CartToCheckout')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %%
# Resample the data to monthly frequency and calculate the mean ReturningVisitorRatio
monthly_rvr = customer_behavior_df['ReturningVisitorRatio'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_rvr.index.strftime('%Y-%m'), y=monthly_rvr.values)
plt.title('Average Monthly ReturningVisitorRatio')
plt.xlabel('Date')
plt.ylabel('Average ReturningVisitorRatio')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %%
# Resample the data to monthly frequency and calculate the mean AvgSessionDuration_sec
monthly_avg_session_duration = customer_behavior_df['AvgSessionDuration_sec'].resample('M').mean()

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=monthly_avg_session_duration.index.strftime('%Y-%m'), y=monthly_avg_session_duration.values)
plt.title('Average Monthly AvgSessionDuration_sec')
plt.xlabel('Date')
plt.ylabel('Average AvgSessionDuration_sec')
plt.xticks(rotation=45)

# Add the value of each bar on top of it
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %% [markdown]
# #### Distribution of features

# %%
# Plotting distributions of numerical columns
fig, axes = plt.subplots(4, 2, figsize=(15, 20))
fig.suptitle('Distributions of Customer Behavior Metrics')

sns.histplot(customer_behavior_df['CTR'], ax=axes[0, 0], kde=True)
axes[0, 0].set_title('CTR Distribution')

sns.histplot(customer_behavior_df['AbandonedCartRate'], ax=axes[0, 1], kde=True)
axes[0, 1].set_title('Abandoned Cart Rate Distribution')

sns.histplot(customer_behavior_df['BounceRate'], ax=axes[1, 0], kde=True)
axes[1, 0].set_title('Bounce Rate Distribution')

sns.histplot(customer_behavior_df['FunnelDrop_ViewToCart'], ax=axes[1, 1], kde=True)
axes[1, 1].set_title('Funnel Drop (View to Cart) Distribution')

sns.histplot(customer_behavior_df['FunnelDrop_CartToCheckout'], ax=axes[2, 0], kde=True)
axes[2, 0].set_title('Funnel Drop (Cart to Checkout) Distribution')

sns.histplot(customer_behavior_df['ReturningVisitorRatio'], ax=axes[2, 1], kde=True)
axes[2, 1].set_title('Returning Visitor Ratio Distribution')

sns.histplot(customer_behavior_df['AvgSessionDuration_sec'], ax=axes[3, 0], kde=True)
axes[3, 0].set_title('Average Session Duration Distribution')

# Hide the last empty subplot
axes[3, 1].axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# #### Correlation matrix

# %%
# Correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(customer_behavior_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
